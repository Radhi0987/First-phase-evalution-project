# %% [markdown]
# # Zomato Restaurant

# %% [markdown]
# Project Description
#
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %%
# importing the reqiured dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression #Logistic Regression is a Machine Learning classification algorithm
from sklearn.linear_model import LinearRegression #Linear Regression is a Machine Learning classification algorithm

# %%
# reading the first csv files
df1=pd.read_csv('Country_Code.csv')
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# reading the second csv files
df2=pd.read_csv('zomato.csv', encoding='latin-1')
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# merging two datasets
df=pd.merge(df1,df2)
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
# checking the shape of data set
df.shape
# Out:
# (9551, 22)

# %%
# checking for datatypes
df.dtypes
# Out:
# Country Code              int64
# Country                  object
# Restaurant ID             int64
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
# checking for null values
df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# There are no null values in the data set

# %%
# finding the mathermatical aspects
df.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   9551.000000   9.551000e+03  9551.000000  9551.000000
# mean      18.365616   9.051128e+06    64.126574    25.854381
# std       56.750546   8.791521e+06    41.467058    11.007935
# min        1.000000   5.300000e+01  -157.948486   -41.330428
# 25%        1.000000   3.019625e+05    77.081343    28.478713
# 50%        1.000000   6.004089e+06    77.191964    28.570469
# 75%        1.000000   1.835229e+07    77.282006    28.642758
# max      216.000000   1.850065e+07   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# Data visualization

# %%
#Plotting the count plot for country 
plt.xticks(rotation=90)
sns.countplot(x='Country',data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %% [markdown]
# Here from the above graph we can see in India Zomato resevice is mostly used

# %%
#Plotting the count plot for Rating color
sns.countplot(x='Rating color',data=df)
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %% [markdown]
# Orange rating(3-3.5)approx is given to most of resurants as compared to other

# %%
#Plotting the count plot for has online delivery 
sns.countplot(x='Has Online delivery',data=df)
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %% [markdown]
# Here we come to know that no of resturants don't provide online delivery

# %%
# count plot for Has Table booking
 
sns.countplot(x='Has Table booking',data=df)
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='count'>

# %% [markdown]
# Online table booking is provided only by few restraunts

# %%
# count plot for Has Switch to order menu
 
sns.countplot(x='Switch to order menu',data=df)
# Out:
# <AxesSubplot:xlabel='Switch to order menu', ylabel='count'>

# %% [markdown]
# Switch to order is not given by single restaurant

# %%
# Checking which cities provide in India has more zomato resturants
ind= df.Country.value_counts()
ind
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
#Changing the Columns Names
print(df.columns)
df.rename(columns={'Has Table booking':'Has_Table_booking','Has Online delivery':'Has_Online_delivery','Average Cost for two':'Average_Cost_for_two','Is delivering now':'Is_delivering_now','Price range':'Price_range','Aggregate rating':'Aggregate_rating','Rating text':'Rating_text','Rating color':'Rating_color'},inplace=True)
# Out:
# Index(['Country Code', 'Country', 'Restaurant ID', 'Restaurant Name', 'City',
#        'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# finding the rating text
ind= df.Rating_text.value_counts()
ind
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating_text, dtype: int64

# %%
# finding the rating text
ind= df.Cuisines.value_counts()
ind
# Out:
# North Indian                                 936
# North Indian, Chinese                        511
# Fast Food                                    354
# Chinese                                      354
# North Indian, Mughlai                        334
#                                             ...
# Cafe, Mexican, Continental                     1
# North Indian, Continental, Asian, Italian      1
# Continental, Cafe                              1
# North Indian, Biryani, Mughlai                 1
# Burger, Greek, Sandwich                        1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
# finding rating color
ind= df.Rating_color.value_counts()
ind
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating_color, dtype: int64

# %%
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
df.Has_Online_delivery.replace(('Yes','No'),(1, 0),inplace=True)
df.Has_Table_booking.replace(('Yes','No'),(1, 0),inplace=True)
df.Is_delivering_now.replace(('Yes','No'),(1, 0),inplace=True)
df.Rating_text.replace(('Not rated','Poor','Good','Average','Very Good','Excellent'),(0,1,2,3,4,5),inplace=True)
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
df.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   9551.000000   9.551000e+03  9551.000000  9551.000000
# mean      18.365616   9.051128e+06    64.126574    25.854381
# std       56.750546   8.791521e+06    41.467058    11.007935
# min        1.000000   5.300000e+01  -157.948486   -41.330428
# 25%        1.000000   3.019625e+05    77.081343    28.478713
# 50%        1.000000   6.004089e+06    77.191964    28.570469
# 75%        1.000000   1.835229e+07    77.282006    28.642758
# max      216.000000   1.850065e+07   174.832089    55.976980
#
#        Average_Cost_for_two  Has_Table_booking  Has_Online_delivery  \
# count           9551.000000        9551.000000          9551.000000
# mean            1199.210763           0.121244             0.256622
# std            16121.183073           0.326428             0.436792
# min                0.000000           0.000000             0.000000
# 25%              250.000000           0.000000             0.000000
# ...

# %%
#finding Correlation between different variables
corr = df.corr()
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Finding the Average Price

# %%
from sklearn.model_selection import train_test_split
#Defining the independent variables and dependent variables
x =df.drop(columns=['Country','Restaurant Name','Restaurant ID','Price_range','City','Address','Currency','Locality','Locality Verbose','Longitude','Latitude','Cuisines','Switch to order menu','Rating_color','Votes'],axis=1)
y =df['Price_range']
#Getting Test and Training Set
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=353)
x_train.head()
y_train.head()
# Out:
# 8696    4
# 1164    1
# 4824    1
# 7574    3
# 2961    3
# Name: Price_range, dtype: int64

# %%
#Prepare a Linear REgression Model
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.42122906685399086

# %%
#Prepairng a Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=105)
DTree=DecisionTreeRegressor(min_samples_leaf=.0001)
DTree.fit(x_train,y_train)
y_predict=DTree.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.9707619021180632

# %% [markdown]
# Here score is good so we can use  Decision Tree Regression Model for predicting the Price

# %% [markdown]
# finding the Average cost of Two

# %%
X=df.drop(columns=['Average_Cost_for_two']).values
Y=df['Average_Cost_for_two'].values
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (7640, 21)
# (1911, 21)
# (7640,)
# (1911,)

# %%
#Prepairng a Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=105)
DTree=DecisionTreeRegressor(min_samples_leaf=.0001)
DTree.fit(x_train,y_train)
y_predict=DTree.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.9719657746586876

# %% [markdown]
# Here we can save Decision tree Regression is good for prediction of Average price of two

# %% [markdown]
# Thank you!!!
